# %% [markdown]
# # Bank Marketing

# %% [markdown]
# #### Source:
#
# [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014
#
# #### Data Set Information:
#
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed
#
# #### Input variables:
# ##### Bank client data
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
#
# ##### Related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mn','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# ##### Other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# ##### Social and economic context attributes:
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# #### Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %% [markdown]
# ----------------------

# %% [markdown]
# #### Información del conjunto de datos:
#
# Los datos están relacionados con campañas de marketing directo de una entidad bancaria portuguesa. Las campañas de marketing se basaron en llamadas telefónicas. A menudo, se requería más de un contacto con el mismo cliente, para poder acceder si el producto (depósito bancario a plazo) estaría ('sí') o no ('no') suscrito.
#
# #### Información de atributos:
#
# #### Variables de entrada:
# ##### Datos del cliente del banco:
# 1 - edad (numérico)
# 2 - trabajo : tipo de trabajo (categórico: 'administrador', 'cuello azul', 'empresario', 'criada', 'administración', 'jubilado', 'autónomo', 'servicios', 'estudiante') ,'técnico','desempleado','desconocido')
# 3 - marital : estado civil (categórico: 'divorciado', 'casado', 'soltero', 'desconocido'; nota: 'divorciado' significa divorciado o viudo)
# 4 - educación (categórico: 'básico.4 años','básico.6 años','básico.9 años','bachillerato','analfabeto','curso.profesional','título.universitario','desconocido')
# 5- mora: tiene credito en mora? (categórico: 'no', 'sí', 'desconocido')
# 6 - vivienda: tiene préstamo de vivienda? (categórico: 'no', 'sí', 'desconocido')
# 7 - préstamo: tiene préstamo personal? (categórico: 'no', 'sí', 'desconocido')
# ##### Relacionado con el último contacto de la campaña actual:
# 8 - contacto: tipo de comunicación de contacto (categórico: 'celular', 'teléfono')
# 9 - mes: último mes de contacto del año (categóricos: 'ene', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: último día de contacto de la semana (categórico: 'lun', 'mar', 'mié', 'jue', 'vie')
# 11 - duración: duración del último contacto, en segundos (numérico). Nota importante: este atributo afecta en gran medida el objetivo de salida (por ejemplo, si la duración = 0, entonces y = 'no'). Sin embargo, la duración no se conoce antes de que se realice una llamada. Además, después del final de la llamada y es obviamente conocido. Por lo tanto, esta entrada solo debe incluirse con fines de referencia y debe descartarse si la intención es tener un modelo predictivo realista.
# ##### Otros atributos:
# 12 - campaña: número de contactos realizados durante esta campaña y para este cliente (numérico, incluye último contacto)
# 13 - pdays: número de días que transcurrieron desde la última vez que se contactó al cliente de una campaña anterior (numérico; 999 significa que el cliente no fue contactado previamente)
# 14 - anterior: número de contactos realizados antes de esta campaña y para este cliente (numérico)
# 15 - poutcome: resultado de la campaña de marketing anterior (categórico: 'fracaso', 'inexistente', 'éxito')
# ##### Atributos del contexto social y económico
# 16 - emp.var.rate: tasa de variación del empleo - indicador trimestral (numérico)
# 17 - cons.price.idx: índice de precios al consumidor - indicador mensual (numérico)
# 18 - cons.conf.idx: índice de confianza del consumidor - indicador mensual (numérico)
# 19 - euribor3m: tasa euribor 3 meses - indicador diario (numérico)
# 20 - nr.employed: número de empleados - indicador trimestral (numérico)
#
# #### Variable de salida (objetivo deseado):
# 21 - y - ¿El cliente ha suscrito un depósito a plazo? (binario: 'sí', 'no')

# %% [markdown]
# -----------------

# %%
# Importamos las librerías
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
bank = pd.read_csv('bank-additional-full.csv', sep=';')
bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank.shape
# Out:
# (41188, 21)

# %%
bank['y'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
bank_copy = bank.copy()

# %%
bank_copy = bank_copy.loc[bank_copy['y'] == 'yes']
bank_copy
# Out:
#        age           job   marital            education  default housing loan  \
# 75      41   blue-collar  divorced             basic.4y  unknown     yes   no
# 83      49  entrepreneur   married    university.degree  unknown     yes   no
# 88      49    technician   married             basic.9y       no      no   no
# 129     41    technician   married  professional.course  unknown     yes   no
# 139     45   blue-collar   married             basic.9y  unknown     yes   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 41174   62       retired   married    university.degree       no     yes   no
# 41178   62       retired   married    university.degree       no      no   no
# 41181   37        admin.   married    university.degree       no     yes   no
# 41183   73       retired   married  professional.course       no     yes   no
# 41186   44    technician   married  professional.course       no      no   no
#
# ...

# %%
bank_copy = bank_copy[['age','y']]

# %%
sns.histplot(data = bank_copy, x = "age", color = "#476599",binwidth = 2)
plt.title("Personas que se suscribieron por rango de edad", fontsize=20)
plt.xlabel("age")
plt.show()

# %% [markdown]
# ### Variable "housing"

# %%
bank_copy = bank.copy()
bank_copy = bank_copy.loc[bank_copy['housing'] == 'yes']
bank_copy
# Out:
#        age         job   marital            education default housing loan  \
# 2       37    services   married          high.school      no     yes   no
# 8       24  technician    single  professional.course      no     yes   no
# 9       25    services    single          high.school      no     yes   no
# 11      25    services    single          high.school      no     yes   no
# 13      57   housemaid  divorced             basic.4y      no     yes   no
# ...    ...         ...       ...                  ...     ...     ...  ...
# 41181   37      admin.   married    university.degree      no     yes   no
# 41182   29  unemployed    single             basic.4y      no     yes   no
# 41183   73     retired   married  professional.course      no     yes   no
# 41185   56     retired   married    university.degree      no     yes   no
# 41187   74     retired   married  professional.course      no     yes   no
#
# ...

# %%
bank_copy = bank_copy.drop(columns=['age','campaign','cons.conf.idx','cons.price.idx','duration','emp.var.rate',
                'euribor3m','nr.employed','pdays','previous','marital','education','default','loan','contact','month',
                'day_of_week','poutcome'])

# %%
bank_copy
# Out:
#               job housing    y
# 2        services     yes   no
# 8      technician     yes   no
# 9        services     yes   no
# 11       services     yes   no
# 13      housemaid     yes   no
# ...           ...     ...  ...
# 41181      admin.     yes  yes
# 41182  unemployed     yes   no
# 41183     retired     yes  yes
# 41185     retired     yes   no
# 41187     retired     yes   no
#
# [21576 rows x 3 columns]

# %%
bank_graph2 = bank_copy.groupby(['job','y']).count()
bank_graph2
# Out:
#                    housing
# job           y
# admin.        no      4819
#               yes      740
# blue-collar   no      4396
#               yes      314
# entrepreneur  no       707
#               yes       72
# housemaid     no       489
#               yes       51
# management    no      1320
#               yes      170
# retired       no       657
#               yes      235
# self-employed no       664
#               yes       76
# services      no      1874
#               yes      176
# student       no       316
#               yes      155
# technician    no      3203
#               yes      413
# unemployed    no       473
#               yes       84
# unknown       no       151
#               yes       21

# %%
bank_graph2 = bank_graph2.reset_index()
bank_graph2
# Out:
#               job    y  housing
# 0          admin.   no     4819
# 1          admin.  yes      740
# 2     blue-collar   no     4396
# 3     blue-collar  yes      314
# 4    entrepreneur   no      707
# 5    entrepreneur  yes       72
# 6       housemaid   no      489
# 7       housemaid  yes       51
# 8      management   no     1320
# 9      management  yes      170
# 10        retired   no      657
# 11        retired  yes      235
# 12  self-employed   no      664
# 13  self-employed  yes       76
# 14       services   no     1874
# 15       services  yes      176
# 16        student   no      316
# 17        student  yes      155
# 18     technician   no     3203
# 19     technician  yes      413
# 20     unemployed   no      473
# 21     unemployed  yes       84
# 22        unknown   no      151
# 23        unknown  yes       21

# %%
bank_graph2.columns
# Out:
# Index(['job', 'y', 'housing'], dtype='object')

# %%
sns.barplot(data = bank_graph2, x = 'job', y = "housing", palette = "mako", ci = None, hue = "y")
sns.set(rc = {'figure.figsize':(16,8)})
plt.xticks(rotation= 45)
plt.xlabel("Jobs")
plt.ylabel("Housing")
plt.title("Respuesta de personas con préstamo de vivienda (segmentado por trabajo)", fontsize=20)
plt.show()

# %%
bank_graph2.columns
# Out:
# Index(['job', 'y', 'housing'], dtype='object')

# %%
label = bank_graph2['job'].unique()
label[0]
# Out:
# 'admin.'

# %%
l_values = bank_graph2['housing'].values
l_values
# Out:
# array([4819,  740, 4396,  314,  707,   72,  489,   51, 1320,  170,  657,
#         235,  664,   76, 1874,  176,  316,  155, 3203,  413,  473,   84,
#         151,   21], dtype=int64)

# %%
fig = plt.figure(constrained_layout = True)
gs = gridspec.GridSpec(ncols=8, nrows=8, figure=fig)
c = ["#476599" , "#33B8FF"]

#admin
options = ['no', 'yes']
count = l_values[:2]
fig_ax2 = fig.add_subplot(gs[:2, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[0])

#blue-collar
count = l_values[2:4]
fig_ax2 = fig.add_subplot(gs[:2, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[1])

#entrepreneur
count = l_values[4:6]
fig_ax2 = fig.add_subplot(gs[:2, 4:6])
fig_ax2.pie(count, colors =c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[2])

#housemaid
count = l_values[6:8]
fig_ax2 = fig.add_subplot(gs[:2, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[3])

#management
count = l_values[8:10]
fig_ax2 = fig.add_subplot(gs[2:4, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[4])

#retired
count = l_values[10:12]
fig_ax2 = fig.add_subplot(gs[2:4, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[5])

#self-employed
count = l_values[12:14]
fig_ax2 = fig.add_subplot(gs[2:4, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[6])

#services
count = l_values[14:16]
fig_ax2 = fig.add_subplot(gs[2:4, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[7])

#student
count = l_values[16:18]
fig_ax2 = fig.add_subplot(gs[4:6, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[8])

#technician
count = l_values[18:20]
fig_ax2 = fig.add_subplot(gs[4:6, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[9])

#unemployed
count = l_values[20:22]
fig_ax2 = fig.add_subplot(gs[4:6, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[10])

#unknown
count = l_values[22:24]
fig_ax2 = fig.add_subplot(gs[4:6, 6:])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[11])

plt.suptitle("Porcentaje de respuestas para el sector que contaba con un préstamo de vivienda\n", fontsize=20)

plt.show()

# %% [markdown]
# ### Variable "loan"

# %%
bank_copy = bank.copy()
bank_copy = bank_copy.loc[bank_copy['loan'] == 'yes']
bank_copy
# Out:
#        age          job   marital            education  default housing loan  \
# 4       56     services   married          high.school       no      no  yes
# 12      29  blue-collar    single          high.school       no      no  yes
# 15      54      retired   married             basic.9y  unknown     yes  yes
# 17      46  blue-collar   married             basic.6y  unknown     yes  yes
# 18      50  blue-collar   married             basic.9y       no     yes  yes
# ...    ...          ...       ...                  ...      ...     ...  ...
# 41098   29      student    single          high.school       no     yes  yes
# 41111   46       admin.    single    university.degree       no      no  yes
# 41127   61       admin.   married          high.school       no     yes  yes
# 41143   29   technician    single  professional.course       no      no  yes
# 41176   38    housemaid  divorced          high.school       no     yes  yes
#
# ...

# %%
bank_copy = bank_copy.drop(columns=['age','campaign','cons.conf.idx','cons.price.idx','duration','emp.var.rate',
                'euribor3m','nr.employed','pdays','previous','marital','education','default','housing','contact','month',
                'day_of_week','poutcome'])

# %%
bank_graph2 = bank_copy.groupby(['job','y']).count()
bank_graph2
# Out:
#                    loan
# job           y
# admin.        no   1506
#               yes   204
# blue-collar   no   1283
#               yes    83
# entrepreneur  no    195
#               yes    11
# housemaid     no    139
#               yes    15
# management    no    395
#               yes    44
# retired       no    178
#               yes    62
# self-employed no    170
#               yes    25
# services      no    549
#               yes    52
# student       no     87
#               yes    55
# technician    no    880
#               yes   109
# unemployed    no    131
#               yes    18
# unknown       no     52
#               yes     5

# %%
bank_graph2 = bank_graph2.reset_index()
bank_graph2
# Out:
#               job    y  loan
# 0          admin.   no  1506
# 1          admin.  yes   204
# 2     blue-collar   no  1283
# 3     blue-collar  yes    83
# 4    entrepreneur   no   195
# 5    entrepreneur  yes    11
# 6       housemaid   no   139
# 7       housemaid  yes    15
# 8      management   no   395
# 9      management  yes    44
# 10        retired   no   178
# 11        retired  yes    62
# 12  self-employed   no   170
# 13  self-employed  yes    25
# 14       services   no   549
# 15       services  yes    52
# 16        student   no    87
# 17        student  yes    55
# 18     technician   no   880
# 19     technician  yes   109
# 20     unemployed   no   131
# 21     unemployed  yes    18
# 22        unknown   no    52
# 23        unknown  yes     5

# %%
sns.barplot(data = bank_graph2, x = 'job', y = "loan", palette = "mako", ci = None, hue = "y")
sns.set(rc = {'figure.figsize':(16,8)})
plt.xticks(rotation= 45)
plt.xlabel("Jobs")
plt.ylabel("Loan")
plt.title("Respuesta de personas con préstamo personal (segmentado por trabajo)", fontsize=20)
plt.show()

# %%
bank_graph2.columns
# Out:
# Index(['job', 'y', 'loan'], dtype='object')

# %%
label = bank_graph2['job'].unique()
label[0]
# Out:
# 'admin.'

# %%
label
# Out:
# array(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'], dtype=object)

# %%
l_values = bank_graph2['loan'].values
l_values
# Out:
# array([1506,  204, 1283,   83,  195,   11,  139,   15,  395,   44,  178,
#          62,  170,   25,  549,   52,   87,   55,  880,  109,  131,   18,
#          52,    5], dtype=int64)

# %%
l_values[2:4]
# Out:
# array([1283,   83], dtype=int64)

# %%
fig = plt.figure(constrained_layout = True)
gs = gridspec.GridSpec(ncols=8, nrows=8, figure=fig)
c = ["#476599" , "#33B8FF"]

#admin
options = ['no', 'yes']
count = l_values[:2]
fig_ax2 = fig.add_subplot(gs[:2, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[0])

#blue-collar
count = l_values[2:4]
fig_ax2 = fig.add_subplot(gs[:2, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[1])

#entrepreneur
count = l_values[4:6]
fig_ax2 = fig.add_subplot(gs[:2, 4:6])
fig_ax2.pie(count, colors =c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[2])

#housemaid
count = l_values[6:8]
fig_ax2 = fig.add_subplot(gs[:2, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[3])

#management
count = l_values[8:10]
fig_ax2 = fig.add_subplot(gs[2:4, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[4])

#retired
count = l_values[10:12]
fig_ax2 = fig.add_subplot(gs[2:4, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[5])

#self-employed
count = l_values[12:14]
fig_ax2 = fig.add_subplot(gs[2:4, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[6])

#services
count = l_values[14:16]
fig_ax2 = fig.add_subplot(gs[2:4, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[7])

#student
count = l_values[16:18]
fig_ax2 = fig.add_subplot(gs[4:6, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[8])

#technician
count = l_values[18:20]
fig_ax2 = fig.add_subplot(gs[4:6, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[9])

#unemployed
count = l_values[20:22]
fig_ax2 = fig.add_subplot(gs[4:6, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[10])

#unknown
count = l_values[22:24]
fig_ax2 = fig.add_subplot(gs[4:6, 6:])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[11])

plt.suptitle("Porcentaje de respuestas para el sector que contaba con un préstamo personal\n", fontsize=20)

plt.show()

# %% [markdown]
# ### Variable "default"

# %%
bank_copy = bank[['education','default']]
bank_copy
# Out:
#                  education  default
# 0                 basic.4y       no
# 1              high.school  unknown
# 2              high.school       no
# 3                 basic.6y       no
# 4              high.school       no
# ...                    ...      ...
# 41183  professional.course       no
# 41184  professional.course       no
# 41185    university.degree       no
# 41186  professional.course       no
# 41187  professional.course       no
#
# [41188 rows x 2 columns]

# %%
bank_copy.loc[bank_copy['default']=='yes']
# Out:
#                  education default
# 21580  professional.course     yes
# 21581  professional.course     yes
# 24866          high.school     yes

# %% [markdown]
# Concluimos que pocas personas tienen en mora.

# %% [markdown]
# ### Variable "education"

# %%
bank_graph3 = bank[['education','y']]
bank_graph3 = bank_graph3.groupby(['education','y']).size().reset_index(name= 'count')
bank_graph3
# Out:
#               education    y  count
# 0              basic.4y   no   3748
# 1              basic.4y  yes    428
# 2              basic.6y   no   2104
# 3              basic.6y  yes    188
# 4              basic.9y   no   5572
# 5              basic.9y  yes    473
# 6           high.school   no   8484
# 7           high.school  yes   1031
# 8            illiterate   no     14
# 9            illiterate  yes      4
# 10  professional.course   no   4648
# 11  professional.course  yes    595
# 12    university.degree   no  10498
# 13    university.degree  yes   1670
# 14              unknown   no   1480
# 15              unknown  yes    251

# %%
sns.barplot(data = bank_graph3, x = 'education', y= 'count', palette = "mako", ci = None, hue = "y")
sns.set(rc = {'figure.figsize':(16,8)})
plt.xticks(rotation= 45)
plt.xlabel("Education")
plt.ylabel("Count")
plt.title("Respuesta de personas segmentado por su nivel educativo", fontsize=20)
plt.show()

# %%
label = bank_graph3['education'].unique()
label
# Out:
# array(['basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'illiterate',
#        'professional.course', 'university.degree', 'unknown'],
#       dtype=object)

# %%
l_values = bank_graph3['count']
l_values[:2]
# Out:
# 0    3748
# 1     428
# Name: count, dtype: int64

# %%
fig = plt.figure(constrained_layout = True)
gs = gridspec.GridSpec(ncols=8, nrows=8, figure=fig)
c = ["#476599" , "#33B8FF"]

#bassic.4y
options = ['no', 'yes']
count = l_values[:2]
fig_ax2 = fig.add_subplot(gs[:2, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[0])

#bassic.6y
options = ['no', 'yes']
count = l_values[2:4]
fig_ax2 = fig.add_subplot(gs[:2, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[1])

#bassic.9y
options = ['no', 'yes']
count = l_values[4:6]
fig_ax2 = fig.add_subplot(gs[:2, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[2])

#high.school
options = ['no', 'yes']
count = l_values[6:8]
fig_ax2 = fig.add_subplot(gs[:2, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[3])

#illiterate
options = ['no', 'yes']
count = l_values[8:10]
fig_ax2 = fig.add_subplot(gs[2:4, :2])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[4])

#professional.course
options = ['no', 'yes']
count = l_values[10:12]
fig_ax2 = fig.add_subplot(gs[2:4, 2:4])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[5])

#university.degree
options = ['no', 'yes']
count = l_values[12:14]
fig_ax2 = fig.add_subplot(gs[2:4, 4:6])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[6])

#unknow
options = ['no', 'yes']
count = l_values[14:16]
fig_ax2 = fig.add_subplot(gs[2:4, 6:8])
fig_ax2.pie(count, colors = c, 
            labels = options, autopct = "%1.0f%%")
fig_ax2.set_title(label[7])

plt.suptitle("Porcentaje de respuestas segmentado por nivel educativo\n", fontsize=20)

plt.show()
